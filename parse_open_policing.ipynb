# %%
import pandas as pd

import os

# %%
def list_all_files(directory):
    # Loop over all directories and files in the given directory
    paths = []
    for dirpath, dirnames, filenames in os.walk(directory):
        for filename in filenames:
            # Full path of the file
            full_path = os.path.join(dirpath, filename)
            if '.feather' in filename:
                paths.append(full_path)
    return paths

# Example usage:
directory_path = 'open_policing'  # Replace with your directory path
files = list_all_files(directory_path)

# %%
files
# Out:
# ['open_policing/yg821jf8611_nc_statewide_2020_04_01.csv/nc_statewide_2020_04_01.feather',
#  'open_policing/yg821jf8611_nc_charlotte_2020_04_01.csv/nc_charlotte_2020_04_01.feather',
#  'open_policing/yg821jf8611_nc_winston-salem_2020_04_01.csv/nc_winston-salem_2020_04_01.feather',
#  'open_policing/yg821jf8611_nc_durham_2020_04_01.csv/nc_durham_2020_04_01.feather',
#  'open_policing/yg821jf8611_nc_greensboro_2020_04_01.csv/nc_greensboro_2020_04_01.feather',
#  'open_policing/yg821jf8611_nc_raleigh_2020_04_01.csv/nc_raleigh_2020_04_01.feather',
#  'open_policing/yg821jf8611_nc_fayetteville_2020_04_01.csv/nc_fayetteville_2020_04_01.feather']

# %%
reversed(files)[-2:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 reversed(files)[-2:]
#
# TypeError: 'list_reverseiterator' object is not subscriptable

# %%
output_file = 'policing_data_products/nc_agg.hdf'
#for f in reversed(files):
for f in files[:1]:
    df_init = pd.read_feather(f)
    #df_init.to_feather(f[:-4] + '.feather')
    df_init['file'] = f
    #df = dd.concat([df, df_init], axis=1, ignore_index=True)
    #dfs.append(df_init)
    print(f)
    df_init.astype(str).to_hdf(output_file, key='df', index=False, append=True)

#df = pd.concat(dfs, axis=1, ignore_index=True)
# Out:
# open_policing/yg821jf8611_nc_statewide_2020_04_01.csv/nc_statewide_2020_04_01.feather

# %%
df_init = pd.read_hdf('output_file', 'df')
df_init.to_feather('policing_data_products/nc_agg.feather')

# %%
df_init
# Out:
#          raw_row_number        date      time                 location  \
# 0                  3254  2000-01-01  17:20:00                  Unknown
# 1                  3259  2000-01-02  11:40:00                  Unknown
# 2                  3281  2000-01-02  02:41:00                  Unknown
# 3                  3282  2000-01-23  03:35:00                  Unknown
# 4                  3283  2000-01-02  16:45:00                  Unknown
# ...                 ...         ...       ...                      ...
# 1598448        20196581  2015-10-29  09:12:00  nan, Mecklenburg County
# 1598449        20196582  2015-10-29  09:35:00  nan, Mecklenburg County
# 1598450        20196583  2015-10-29  10:30:00  nan, Mecklenburg County
# 1598451        20196584  2015-10-29  09:25:00  nan, Mecklenburg County
# 1598452        20196585  2015-10-30  22:46:00  nan, Mecklenburg County
#
#                 county_name  subject_age subject_race subject_sex  \
# 0                      None         38.0        black      female
# 1                      None         33.0     hispanic        male
# 2                      None         23.0        white        male
# 3                      None         23.0        white      female
# 4                      None         23.0        white      female
# ...                     ...          ...          ...         ...
# 1598448  Mecklenburg County         23.0        white        male
# 1598449  Mecklenburg County         22.0        white        male
# 1598450  Mecklenburg County         23.0        black        male
# 1598451  Mecklenburg County         59.0        white      female
# 1598452  Mecklenburg County         22.0        black        male
#
#         officer_id_hash                             department_name  ...  \
# 0            22e35044ed  UNC Charlotte University Police Department  ...
# 1            22e35044ed  UNC Charlotte University Police Department  ...
# 2            22e35044ed  UNC Charlotte University Police Department  ...
# 3            22e35044ed  UNC Charlotte University Police Department  ...
# 4            22e35044ed  UNC Charlotte University Police Department  ...
# ...                 ...                                         ...  ...
# 1598448      b4e80820ef  UNC Charlotte University Police Department  ...
# 1598449      b4e80820ef  UNC Charlotte University Police Department  ...
# 1598450      098aa2cef7  UNC Charlotte University Police Department  ...
# 1598451      e6652f3f3d  UNC Charlotte University Police Department  ...
# 1598452      eaeaf19018  UNC Charlotte University Police Department  ...
#
#         search_person  search_vehicle  search_basis  reason_for_frisk  \
# 0               False           False          None              None
# 1               False           False          None              None
# 2               False           False          None              None
# 3               False           False          None              None
# 4               False           False          None              None
# ...               ...             ...           ...               ...
# 1598448         False           False          None              None
# 1598449         False           False          None              None
# 1598450         False           False          None              None
# 1598451         False           False          None              None
# 1598452         False           False          None              None
#
#         reason_for_search               reason_for_stop raw_Ethnicity  \
# 0                    None       Safe Movement Violation             N
# 1                    None  Vehicle Regulatory Violation             H
# 2                    None   Vehicle Equipment Violation             N
# 3                    None  Vehicle Regulatory Violation             N
# 4                    None       Safe Movement Violation             N
# ...                   ...                           ...           ...
# 1598448              None     Stop Light/Sign Violation             N
# 1598449              None     Stop Light/Sign Violation             N
# 1598450              None     Stop Light/Sign Violation             N
# 1598451              None  Vehicle Regulatory Violation             N
# 1598452              None     Stop Light/Sign Violation             N
#
#         raw_Race  raw_action_description  \
# 0              B          Verbal Warning
# 1              W         Citation Issued
# 2              W         Citation Issued
# 3              W         Citation Issued
# 4              W          Verbal Warning
# ...          ...                     ...
# 1598448        W         Citation Issued
# 1598449        W         Citation Issued
# 1598450        B         Citation Issued
# 1598451        W         Written Warning
# 1598452        B         Written Warning
#
#                                                       file
# 0        open_policing/yg821jf8611_nc_charlotte_2020_04...
# 1        open_policing/yg821jf8611_nc_charlotte_2020_04...
# 2        open_policing/yg821jf8611_nc_charlotte_2020_04...
# 3        open_policing/yg821jf8611_nc_charlotte_2020_04...
# 4        open_policing/yg821jf8611_nc_charlotte_2020_04...
# ...                                                    ...
# 1598448  open_policing/yg821jf8611_nc_charlotte_2020_04...
# 1598449  open_policing/yg821jf8611_nc_charlotte_2020_04...
# 1598450  open_policing/yg821jf8611_nc_charlotte_2020_04...
# 1598451  open_policing/yg821jf8611_nc_charlotte_2020_04...
# 1598452  open_policing/yg821jf8611_nc_charlotte_2020_04...
#
# [1598453 rows x 30 columns]

# %%
df_init.columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'location', 'county_name',
#        'subject_age', 'subject_race', 'subject_sex', 'officer_id_hash',
#        'department_name', 'type', 'arrest_made', 'citation_issued',
#        'warning_issued', 'outcome', 'contraband_found', 'contraband_drugs',
#        'contraband_weapons', 'frisk_performed', 'search_conducted',
#        'search_person', 'search_vehicle', 'search_basis', 'reason_for_frisk',
#        'reason_for_search', 'reason_for_stop', 'raw_Ethnicity', 'raw_Race',
#        'raw_action_description', 'file'],
#       dtype='object')

# %%
df_init = pd.read_csv('open_policing/yg821jf8611_nc_greensboro_2020_04_01.csv/nc_greensboro_2020_04_01.csv')

# %%
df_init
# Out:
#         raw_row_number        date      time              location  \
# 0                74627  2000-01-06  23:25:00               Unknown
# 1                74634  2000-01-06  23:55:00               Unknown
# 2                74638  2000-01-06  21:36:00               Unknown
# 3                74650  2000-01-07  02:30:00               Unknown
# 4                74654  2000-01-07  04:15:00               Unknown
# ...                ...         ...       ...                   ...
# 600026        20247742  2015-12-31  00:25:00  nan, Guilford County
# 600027        20247743  2015-12-31  21:25:00  nan, Guilford County
# 600028        20247744  2015-12-27  18:00:00  nan, Guilford County
# 600029        20247745  2015-12-31  15:00:00  nan, Guilford County
# 600030        20247746  2015-12-05  00:33:00  nan, Guilford County
#
#             county_name  subject_age subject_race subject_sex officer_id_hash  \
# 0                   NaN         23.0        white      female      22e35044ed
# 1                   NaN         19.0        white      female      22e35044ed
# 2                   NaN         22.0        black        male      22e35044ed
# 3                   NaN         14.0        black        male      22e35044ed
# 4                   NaN         19.0        black        male      22e35044ed
# ...                 ...          ...          ...         ...             ...
# 600026  Guilford County         55.0        white        male      a1aceff0fb
# 600027  Guilford County         24.0        black        male      74c7f6883d
# 600028  Guilford County         34.0        black      female      1a6db5ae41
# 600029  Guilford County         39.0        black        male      5e85383c69
# 600030  Guilford County         51.0        black        male      66a66d91f8
#
#                                     department_name  ... search_conducted  \
# 0       UNC Greensboro University Police Department  ...            False
# 1       UNC Greensboro University Police Department  ...            False
# 2       UNC Greensboro University Police Department  ...            False
# 3       UNC Greensboro University Police Department  ...            False
# 4       UNC Greensboro University Police Department  ...            False
# ...                                             ...  ...              ...
# 600026                 Greensboro Police Department  ...             True
# 600027                 Greensboro Police Department  ...             True
# 600028                 Greensboro Police Department  ...             True
# 600029                 Greensboro Police Department  ...             True
# 600030                 Greensboro Police Department  ...             True
#
#         search_person  search_vehicle    search_basis reason_for_frisk  \
# 0               False           False             NaN              NaN
# 1               False           False             NaN              NaN
# 2               False           False             NaN              NaN
# 3               False           False             NaN              NaN
# 4               False           False             NaN              NaN
# ...               ...             ...             ...              ...
# 600026           True            True  probable cause              NaN
# 600027           True            True  probable cause              NaN
# 600028           True            True         consent              NaN
# 600029           True            True  probable cause              NaN
# 600030           True            True  probable cause              NaN
#
#                                         reason_for_search  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 600026                Observation of Suspected Contraband
# 600027                Observation of Suspected Contraband
# 600028  Erratic/Suspicious Behavior|Observation of Sus...
# 600029                Observation of Suspected Contraband
# 600030                Observation of Suspected Contraband
#
#                      reason_for_stop raw_Ethnicity  raw_Race  \
# 0              Speed Limit Violation             N         W
# 1              Speed Limit Violation             N         W
# 2            Safe Movement Violation             N         B
# 3            Safe Movement Violation             N         B
# 4            Safe Movement Violation             N         B
# ...                              ...           ...       ...
# 600026         Speed Limit Violation             N         W
# 600027  Vehicle Regulatory Violation             N         B
# 600028                 Investigation             N         B
# 600029         Speed Limit Violation             N         B
# 600030         Speed Limit Violation             N         B
#
#         raw_action_description
# 0              Citation Issued
# 1              Citation Issued
# 2              Citation Issued
# 3              No Action Taken
# 4               Verbal Warning
# ...                        ...
# 600026         Citation Issued
# 600027         Citation Issued
# 600028          Verbal Warning
# 600029          On-View Arrest
# 600030         Citation Issued
#
# [600031 rows x 29 columns]

# %%
df_init.to_feather('test.feather')

# %%
pd.read_feather('test.feather')
# Out:
#         raw_row_number        date      time              location  \
# 0                74627  2000-01-06  23:25:00               Unknown
# 1                74634  2000-01-06  23:55:00               Unknown
# 2                74638  2000-01-06  21:36:00               Unknown
# 3                74650  2000-01-07  02:30:00               Unknown
# 4                74654  2000-01-07  04:15:00               Unknown
# ...                ...         ...       ...                   ...
# 600026        20247742  2015-12-31  00:25:00  nan, Guilford County
# 600027        20247743  2015-12-31  21:25:00  nan, Guilford County
# 600028        20247744  2015-12-27  18:00:00  nan, Guilford County
# 600029        20247745  2015-12-31  15:00:00  nan, Guilford County
# 600030        20247746  2015-12-05  00:33:00  nan, Guilford County
#
#             county_name  subject_age subject_race subject_sex officer_id_hash  \
# 0                  None         23.0        white      female      22e35044ed
# 1                  None         19.0        white      female      22e35044ed
# 2                  None         22.0        black        male      22e35044ed
# 3                  None         14.0        black        male      22e35044ed
# 4                  None         19.0        black        male      22e35044ed
# ...                 ...          ...          ...         ...             ...
# 600026  Guilford County         55.0        white        male      a1aceff0fb
# 600027  Guilford County         24.0        black        male      74c7f6883d
# 600028  Guilford County         34.0        black      female      1a6db5ae41
# 600029  Guilford County         39.0        black        male      5e85383c69
# 600030  Guilford County         51.0        black        male      66a66d91f8
#
#                                     department_name  ... search_conducted  \
# 0       UNC Greensboro University Police Department  ...            False
# 1       UNC Greensboro University Police Department  ...            False
# 2       UNC Greensboro University Police Department  ...            False
# 3       UNC Greensboro University Police Department  ...            False
# 4       UNC Greensboro University Police Department  ...            False
# ...                                             ...  ...              ...
# 600026                 Greensboro Police Department  ...             True
# 600027                 Greensboro Police Department  ...             True
# 600028                 Greensboro Police Department  ...             True
# 600029                 Greensboro Police Department  ...             True
# 600030                 Greensboro Police Department  ...             True
#
#         search_person  search_vehicle    search_basis reason_for_frisk  \
# 0               False           False            None             None
# 1               False           False            None             None
# 2               False           False            None             None
# 3               False           False            None             None
# 4               False           False            None             None
# ...               ...             ...             ...              ...
# 600026           True            True  probable cause             None
# 600027           True            True  probable cause             None
# 600028           True            True         consent             None
# 600029           True            True  probable cause             None
# 600030           True            True  probable cause             None
#
#                                         reason_for_search  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 600026                Observation of Suspected Contraband
# 600027                Observation of Suspected Contraband
# 600028  Erratic/Suspicious Behavior|Observation of Sus...
# 600029                Observation of Suspected Contraband
# 600030                Observation of Suspected Contraband
#
#                      reason_for_stop raw_Ethnicity  raw_Race  \
# 0              Speed Limit Violation             N         W
# 1              Speed Limit Violation             N         W
# 2            Safe Movement Violation             N         B
# 3            Safe Movement Violation             N         B
# 4            Safe Movement Violation             N         B
# ...                              ...           ...       ...
# 600026         Speed Limit Violation             N         W
# 600027  Vehicle Regulatory Violation             N         B
# 600028                 Investigation             N         B
# 600029         Speed Limit Violation             N         B
# 600030         Speed Limit Violation             N         B
#
#         raw_action_description
# 0              Citation Issued
# 1              Citation Issued
# 2              Citation Issued
# 3              No Action Taken
# 4               Verbal Warning
# ...                        ...
# 600026         Citation Issued
# 600027         Citation Issued
# 600028          Verbal Warning
# 600029          On-View Arrest
# 600030         Citation Issued
#
# [600031 rows x 29 columns]

# %%
dfs[0]
# Out:
#         raw_row_number        date      time                location  \
# 0                 5434  2000-01-07  10:31:00                 Unknown
# 1                 5435  2000-01-08  21:41:00                 Unknown
# 2                 5436  2000-01-08  01:15:00                 Unknown
# 3                 5437  2000-01-10  20:25:00                 Unknown
# 4                 5438  2000-01-11  01:56:00                 Unknown
# ...                ...         ...       ...                     ...
# 486993        20280181  2015-12-31  23:48:00  nan, Cumberland County
# 486994        20280182  2015-12-31  23:54:00  nan, Cumberland County
# 486995        20280183  2015-12-29  14:45:00  nan, Cumberland County
# 486996        20280184  2015-12-08  13:00:00  nan, Cumberland County
# 486997        20280185  2015-12-31  18:31:00  nan, Cumberland County
#
#               county_name  subject_age subject_race subject_sex  \
# 0                     NaN         22.0        black        male
# 1                     NaN         20.0        black      female
# 2                     NaN         22.0        black      female
# 3                     NaN         27.0        white      female
# 4                     NaN         22.0     hispanic        male
# ...                   ...          ...          ...         ...
# 486993  Cumberland County         20.0        white        male
# 486994  Cumberland County         25.0        white        male
# 486995  Cumberland County         23.0        black        male
# 486996  Cumberland County         26.0        black        male
# 486997  Cumberland County         26.0     hispanic        male
#
#        officer_id_hash                                  department_name  ...  \
# 0           22e35044ed  Fayetteville State University Police Department  ...
# 1           22e35044ed  Fayetteville State University Police Department  ...
# 2           22e35044ed  Fayetteville State University Police Department  ...
# 3           22e35044ed  Fayetteville State University Police Department  ...
# 4           22e35044ed  Fayetteville State University Police Department  ...
# ...                ...                                              ...  ...
# 486993      cee02f66d8                   Fayetteville Police Department  ...
# 486994      cee02f66d8                   Fayetteville Police Department  ...
# 486995      2f5f7baaa0                   Fayetteville Police Department  ...
# 486996      5fc1615650                   Fayetteville Police Department  ...
# 486997      cee02f66d8                   Fayetteville Police Department  ...
#
#        search_person  search_vehicle    search_basis  reason_for_frisk  \
# 0              False           False             NaN               NaN
# 1              False           False             NaN               NaN
# 2              False           False             NaN               NaN
# 3              False           False             NaN               NaN
# 4              False           False             NaN               NaN
# ...              ...             ...             ...               ...
# 486993         False           False             NaN               NaN
# 486994         False           False             NaN               NaN
# 486995         False           False             NaN               NaN
# 486996          True            True  probable cause               NaN
# 486997          True            True           other               NaN
#
#                           reason_for_search                reason_for_stop  \
# 0                                       NaN          Speed Limit Violation
# 1                                       NaN      Stop Light/Sign Violation
# 2                                       NaN      Stop Light/Sign Violation
# 3                                       NaN      Stop Light/Sign Violation
# 4                                       NaN                  Investigation
# ...                                     ...                            ...
# 486993                                  NaN          Speed Limit Violation
# 486994                                  NaN  Other Motor Vehicle Violation
# 486995                                  NaN        Safe Movement Violation
# 486996  Observation of Suspected Contraband    Vehicle Equipment Violation
# 486997          Erratic/Suspicious Behavior          Speed Limit Violation
#
#        raw_Ethnicity raw_Race  raw_action_description  \
# 0                  N        B          Verbal Warning
# 1                  N        B         Citation Issued
# 2                  N        B          Verbal Warning
# 3                  N        W          Verbal Warning
# 4                  H        U          Verbal Warning
# ...              ...      ...                     ...
# 486993             N        W         Written Warning
# 486994             N        W         Written Warning
# 486995             N        B         Written Warning
# 486996             N        B          On-View Arrest
# 486997             H        W          On-View Arrest
#
#                                                      file
# 0       open_policing/yg821jf8611_nc_fayetteville_2020...
# 1       open_policing/yg821jf8611_nc_fayetteville_2020...
# 2       open_policing/yg821jf8611_nc_fayetteville_2020...
# 3       open_policing/yg821jf8611_nc_fayetteville_2020...
# 4       open_policing/yg821jf8611_nc_fayetteville_2020...
# ...                                                   ...
# 486993  open_policing/yg821jf8611_nc_fayetteville_2020...
# 486994  open_policing/yg821jf8611_nc_fayetteville_2020...
# 486995  open_policing/yg821jf8611_nc_fayetteville_2020...
# 486996  open_policing/yg821jf8611_nc_fayetteville_2020...
# 486997  open_policing/yg821jf8611_nc_fayetteville_2020...
#
# [486998 rows x 30 columns]

# %%
dfs[3]
# Out:
#         raw_row_number        date      time               location  \
# 0              1219541  2001-12-28      None  Durham, Durham County
# 1              1221117  2002-01-02  04:00:00  Durham, Durham County
# 2              1221124  2002-01-02      None  Durham, Durham County
# 3              1221133  2002-01-02  19:50:00  Durham, Durham County
# 4              1221146  2002-01-02  20:45:00  Durham, Durham County
# ...                ...         ...       ...                    ...
# 326019        20266702  2015-12-03  21:10:00     nan, Durham County
# 326020        20266703  2015-12-04  03:20:00     nan, Durham County
# 326021        20280195  2015-01-28  10:17:00  Durham, Durham County
# 326022        20280197  2015-01-28  13:41:00  Durham, Durham County
# 326023        20280228  2013-11-01  04:23:00  Durham, Durham County
#
#           county_name  subject_age            subject_race subject_sex  \
# 0       Durham County         22.0                   black      female
# 1       Durham County         28.0                hispanic        male
# 2       Durham County         21.0                   black        male
# 3       Durham County         28.0                   black      female
# 4       Durham County         36.0                   black      female
# ...               ...          ...                     ...         ...
# 326019  Durham County         23.0                   black        male
# 326020  Durham County         32.0  asian/pacific islander      female
# 326021  Durham County         31.0                   black        male
# 326022  Durham County         21.0                   black      female
# 326023  Durham County         32.0                   black      female
#
#        officer_id_hash                 department_name  ... search_person  \
# 0           5b9908c1a5        Durham Police Department  ...         False
# 1           0c140e68b5        Durham Police Department  ...         False
# 2           0c140e68b5        Durham Police Department  ...         False
# 3           41b05be9b1        Durham Police Department  ...         False
# 4           41b05be9b1        Durham Police Department  ...         False
# ...                ...                             ...  ...           ...
# 326019      72b606b024        Durham Police Department  ...         False
# 326020      a4d178e9f0        Durham Police Department  ...          True
# 326021      6c39e1a069  Durham County Sheriff's Office  ...         False
# 326022      6c39e1a069  Durham County Sheriff's Office  ...         False
# 326023      0fbc3d0948  Durham County Sheriff's Office  ...         False
#
#         search_vehicle    search_basis  reason_for_frisk  \
# 0                False            None              None
# 1                False            None              None
# 2                False            None              None
# 3                False            None              None
# 4                False            None              None
# ...                ...             ...               ...
# 326019           False         consent              None
# 326020            True  probable cause              None
# 326021           False            None              None
# 326022           False            None              None
# 326023           False            None              None
#
#                           reason_for_search               reason_for_stop  \
# 0                                      None                 Investigation
# 1                                      None     Stop Light/Sign Violation
# 2                                      None   Vehicle Equipment Violation
# 3                                      None  Vehicle Regulatory Violation
# 4                                      None  Vehicle Regulatory Violation
# ...                                     ...                           ...
# 326019           Other Official Information     Stop Light/Sign Violation
# 326020  Observation of Suspected Contraband                 Investigation
# 326021                                 None         Speed Limit Violation
# 326022                                 None         Speed Limit Violation
# 326023                                 None         Speed Limit Violation
#
#        raw_Ethnicity raw_Race  raw_action_description  \
# 0                  N        B          Verbal Warning
# 1                  H        W         Citation Issued
# 2                  N        B          Verbal Warning
# 3                  N        B         Citation Issued
# 4                  N        B         Written Warning
# ...              ...      ...                     ...
# 326019             N        B         Citation Issued
# 326020             N        A         No Action Taken
# 326021             N        B         Written Warning
# 326022             N        B         Written Warning
# 326023             N        B          Verbal Warning
#
#                                                      file
# 0       open_policing/yg821jf8611_nc_durham_2020_04_01...
# 1       open_policing/yg821jf8611_nc_durham_2020_04_01...
# 2       open_policing/yg821jf8611_nc_durham_2020_04_01...
# 3       open_policing/yg821jf8611_nc_durham_2020_04_01...
# 4       open_policing/yg821jf8611_nc_durham_2020_04_01...
# ...                                                   ...
# 326019  open_policing/yg821jf8611_nc_durham_2020_04_01...
# 326020  open_policing/yg821jf8611_nc_durham_2020_04_01...
# 326021  open_policing/yg821jf8611_nc_durham_2020_04_01...
# 326022  open_policing/yg821jf8611_nc_durham_2020_04_01...
# 326023  open_policing/yg821jf8611_nc_durham_2020_04_01...
#
# [326024 rows x 30 columns]

# %%
df.types
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 df.types
#
# NameError: name 'df' is not defined
